# %%
#load "LoadBaseToolWPF.csx"
using BaseTool;
# Out:
# c:\Users\zeros\Documents\【项目文件夹】\【常用】草稿文档\CSharp\LoadBaseToolWPF.csx(1,1): error CS0006: 未能找到元数据文件“C:\Users\zeros\Documents\VisualStudioCode\ToolsRepository_WPF\BaseTool\bin\Debug\net8.0-windows7.0\BaseTool.dll”
#
# c:\Users\zeros\Documents\【项目文件夹】\【常用】草稿文档\CSharp\LoadBaseToolWPF.csx(2,1): error CS0006: 未能找到元数据文件“C:\Users\zeros\Documents\VisualStudioCode\ToolsRepository_WPF\SoftwareTools\BaseHSMSTool\bin\Debug\net8.0-windows\BaseHSMSTool.dll”
#
# (2,7): error CS0246: 未能找到类型或命名空间名“BaseTool”(是否缺少 using 指令或程序集引用?)

# %%
//使用查表法计算CRC16   高效
//CRC高位字节值表
static byte[] _auchCRCHi = {
    
    };
/* CRC低位字节值表*/
static byte[] _auchCRCLo = {
    
    };

//CRC16计算
public static ushort CalculateCRC16(byte[] puchMsg, int usDataLen)
{
    byte uchCRCHi = 0xFF;
    byte uchCRCLo = 0xFF;
    uint uIndex;
    uint byteIndex = 0;
    while (usDataLen-- > 0)
    {
        uIndex = (uint)(uchCRCHi ^ puchMsg[byteIndex++]);
        uchCRCHi = (byte)(uchCRCLo ^ _auchCRCHi[uIndex]);
        uchCRCLo = _auchCRCLo[uIndex];
    }
    return ((ushort)(uchCRCHi << 8 | uchCRCLo));
}

byte[] data = new byte[] { 0x01, 0x03, 0x00, 0x00, 0x00, 0x02 };
ushort crc = CalculateCRC16(data, data.Length);
Console.WriteLine("CRC16: " + crc.ToString("X4"));
# Out:
# CRC16: C40B
